# %% [markdown]
# Complete the following exercises. You can submit a Jupyter Notebook or a PDF of your code. If you submit a .py file you need to also include a PDF or attachment of your results.

# %% [markdown]
# **Activity 5.01**: Reading Tabular Data from a Web Page and Creating DataFrames
# In this activity, you have been given a Wikipedia page where you have the GDP of
# all countries listed. You have to create three DataFrames from the three sources
# mentioned on the page (https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)).
# You will have to do the following:
# 1. Open the page in a separate Chrome/Firefox tab and use something like an
# Inspect Element tool to view the source HTML and understand its structure.
# 2. Read the page using bs4.
# 3. Find the table structure you will need to deal with (how many tables are there?).
# 4. Find the right table using bs4.
# 5. Separate the source names and their corresponding data.
# 6. Get the source names from the list of sources you have created.
# 7. Separate the header and data from the data that you separated before for the
# first source only, and then create a DataFrame using that.
# 8. Repeat the last task for the other two data sources.

# %% [markdown]
# Read the page using bs4.

# %%
import requests
from bs4 import BeautifulSoup

def scrape(filename, url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"):
    url = f"{url}"
    
    headers = {
        "User-Agent": (
            "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
            "AppleWebKit/537.36 (KHTML, like Gecko) "
            "Chrome/138.0.0.0 Safari/537.36"
        )
    }

    response = requests.get(url, headers = headers)
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")
    html = soup.prettify()
    lines = "\n".join(html.splitlines())
    with open(f"./{filename}.html", "w", encoding="utf-8") as f:
        f.write(lines)
    return soup

# %%
soup = scrape(filename = "gdp", url = "https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)")

# %% [markdown]
# Find the table structure you will need to deal with.

# %%
from IPython.display import HTML, display
import pandas as pd

with open("./gdp.html", "r", encoding = "utf-8") as fd:
    soup = BeautifulSoup(fd)
    print(soup.table)
    
tables = soup.find_all("table")
table = tables[2]
display(HTML(str(table)))
# Out:
# <table id="mwEQ" style="float:right; padding:3px; border:solid gray 1px; margin-left:5px;">
# <tbody id="mwEg">
# <tr id="mwEw">
# <td id="mwFA">
# <div about="#mwt11" class="timeline-wrapper" data-mw='{"name":"timeline","attrs":{},"body":{"extsrc":"\nImageSize = width:auto height:250 barincrement:40\nPlotArea = left:50 bottom:15 top:10 right:20\nAlignBars = justify\nTimeAxis = orientation:vertical\nDateFormat = x.y\nPeriod = from:0.0 till:35\nScaleMajor = unit:day start:0.0 increment:2\n\nPlotData =\n color:blue width:30\n bar:US from:start till:32.38\n bar:China from:start till:20.85\n bar:Germany from:start till:5.45\n bar:Japan from:start till:4.37\n bar:UK from:start till:4.26\n bar:India from:start till:4.15\n bar:France from:start till:3.59\n bar:Italy from:start till:2.73\n bar:Russia from:start till:2.65\n bar:Brazil from:start till:2.63\n\nPlotData =\n\n bar:US at:32.38 fontsize:S text: 32.38 shift:(-9,0)\n bar:China at:20.85 fontsize:S text: 20.85 shift:(-12,0)\n bar:Germany at:5.45 fontsize:S text: 5.45 shift:(-9,0)\n bar:Japan at:4.37 fontsize:S text: 4.37 shift:(-9,0)\n bar:UK at:4.26 fontsize:S text: 4.26 shift:(-9,0)\n bar:India at:4.15 fontsize:S text: 4.15 shift:(-9,0)\n bar:France at:3.59 fontsize:S text: 3.59 shift:(-9,0)\n bar:Italy at:2.73 fontsize:S text: 2.73 shift:(-9,0)\n bar:Russia at:2.65 fontsize:S text: 2.65 shift:(-9,0)\n bar:Brazil at:2.63 fontsize:S text: 2.63 shift:(-9,0)\nTextData =\n pos:(0,0) text:US$ Tn\n"}}' id="mwFQ" typeof="mw:Extension/timeline">
# <map name="timeline_3rstf1qejcsb9m2ikofjtbn43vh94ct">
# </map>
# <img src="//upload.wikimedia.org/wikipedia/en/timeline/3rstf1qejcsb9m2ikofjtbn43vh94ct.png" usemap="#timeline_3rstf1qejcsb9m2ikofjtbn43vh94ct"/>
# </div>
# </td>
# </tr>
# <tr id="mwFg">
# <td id="mwFw" style="text-align:center; font-size:80%;">
#               Largest economies in the world by nominal GDP in 2026
#               <br id="mwGA"/>
#               according to
#               <a href="https://en.wikipedia.org/wiki/International_Monetary_Fund" id="mwGQ" rel="mw:WikiLink" title="International Monetary Fund">
#                International Monetary Fund
#               </a>
#               projections
#               <sup about="#mwt12" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"group":"n","name":"China-THM"}}' id="cite_ref-China-THM_1-0" rel="dc:references" typeof="mw:Extension/ref">
# <a data-mw-group="n" href="#cite_note-China-THM-1" id="mwGg">
# <span class="mw-reflink-text" id="mwGw">
# <span class="cite-bracket" id="mwHA">
#                   [
#                  </span>
#                  n 1
#                  <span class="cite-bracket" id="mwHQ">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# <sup about="#mwt13" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"IMFOCT2025"}}' id="cite_ref-IMFOCT2025_2-0" rel="dc:references" typeof="mw:Extension/ref">
# <a href="#cite_note-IMFOCT2025-2" id="mwHg">
# <span class="mw-reflink-text" id="mwHw">
# <span class="cite-bracket" id="mwIA">
#                   [
#                  </span>
#                  1
#                  <span class="cite-bracket" id="mwIQ">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </td>
# </tr>
# </tbody>
# </table>
# <table about="#mwt60" class="wikitable sortable sticky-header-multi static-row-numbers" data-mw="{&quot;attribs&quot;:[[{&quot;txt&quot;:&quot;style&quot;,&quot;html&quot;:&quot;&lt;span about=\&quot;#mwt59\&quot; typeof=\&quot;mw:Transclusion\&quot; id=\&quot;mwcw\&quot; data-mw='{\&quot;parts\&quot;:[{\&quot;template\&quot;:{\&quot;target\&quot;:{\&quot;wt\&quot;:\&quot;right\&quot;,\&quot;href\&quot;:\&quot;./Template:Right\&quot;},\&quot;params\&quot;:{},\&quot;i\&quot;:0}}]}'&gt;style=\&quot;text-align:right\&quot;|&lt;/span&gt;&quot;},{&quot;html&quot;:&quot;&quot;}]]}" id="mwdA" style="text-align:right" typeof="mw:ExpandedAttrs">
# <caption id="mwdQ">
#             GDP forecast or estimate (million US$) by country
#            </caption>
# <tbody id="mwdg">
# <tr class="static-row-header" id="mwdw" style="text-align:center;">
# <th id="mweA">
#               Country/Territory
#              </th>
# <th id="mweQ" style="width:7.5em;">
# <a href="https://en.wikipedia.org/wiki/International_Monetary_Fund" id="mweg" rel="mw:WikiLink" title="International Monetary Fund">
#                IMF
#               </a>
# <br id="mwew"/>
#               (
#               <link about="#mwt61" data-mw='{"name":"section","attrs":{"begin":"IMF year"}}' id="mwfA" typeof="mw:Extension/section"/>
#               2026
#               <link about="#mwt62" data-mw='{"name":"section","attrs":{"end":"IMF year"}}' id="mwfQ" typeof="mw:Extension/section"/>
#               )
#               <sup about="#mwt65" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"IMFOCT2025"},"body":{"id":"mw-reference-text-cite_note-IMFOCT2025-2"}}' id="cite_ref-IMFOCT2025_2-1" rel="dc:references" typeof="mw:Extension/ref">
# <a href="#cite_note-IMFOCT2025-2" id="mwfg">
# <span class="mw-reflink-text" id="mwfw">
# <span class="cite-bracket" id="mwgA">
#                   [
#                  </span>
#                  1
#                  <span class="cite-bracket" id="mwgQ">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </th>
# <th id="mwgg" style="width:7.5em;">
# <a class="mw-redirect" href="https://en.wikipedia.org/wiki/World_Bank" id="mwgw" rel="mw:WikiLink" title="World Bank">
#                World Bank
#               </a>
# <br id="mwhA"/>
#               (2025)
#               <sup about="#mwt68" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-8"}}' id="cite_ref-8" rel="dc:references" typeof="mw:Extension/ref">
# <a href="#cite_note-8" id="mwhQ">
# <span class="mw-reflink-text" id="mwhg">
# <span class="cite-bracket" id="mwhw">
#                   [
#                  </span>
#                  6
#                  <span class="cite-bracket" id="mwiA">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </th>
# <th id="mwiQ" style="width:7.5em;">
# <a href="https://en.wikipedia.org/wiki/United_Nations" id="mwig" rel="mw:WikiLink" title="United Nations">
#                United Nations
#               </a>
# <br id="mwiw"/>
#               (2024)
#               <sup about="#mwt71" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"UN"},"body":{"id":"mw-reference-text-cite_note-UN-9"}}' id="cite_ref-UN_9-0" rel="dc:references" typeof="mw:Extension/ref">
# <a href="#cite_note-UN-9" id="mwjA">
# <span class="mw-reflink-text" id="mwjQ">
# <span class="cite-bracket" id="mwjg">
#                   [
#                  </span>
#                  7
#                  <span class="cite-bracket" id="mwjw">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </th>
# </tr>
# <tr class="static-row-header" id="mwkA" style="font-weight:bold;">
# <td id="mwkQ" style="text-align:left">
# <span about="#mwt72" class="flagicon" data-mw='{"parts":[{"template":{"target":{"wt":"noflag","href":"./Template:Noflag"},"params":{"1":{"wt":"World"}},"i":0}}]}' id="mwkg" style="padding-left:25px;" typeof="mw:Transclusion">
# <span typeof="mw:Entity">
# </span>
# </span>
# <span about="#mwt72">
#                World
#               </span>
# </td>
# <td id="mwkw">
# <link about="#mwt73" data-mw='{"name":"section","attrs":{"begin":"IMF value"}}' id="mwlA" typeof="mw:Extension/section"/>
#               126,295,331
#               <link about="#mwt74" data-mw='{"name":"section","attrs":{"end":"IMF value"}}' id="mwlQ" typeof="mw:Extension/section"/>
# </td>
# <td id="mwlg">
#               118,350,166
#              </td>
# <td id="mwlw">
#               100,834,796
#              </td>
# </tr>
# <tr id="mwmA">
# <td about="#mwt75" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"United States"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"},"the":{"wt":"y"}},"i":0}}," "]}' id="mwmQ" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="650" data-file-type="drawing" data-file-width="1235" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_the_United_States.svg" src="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/40px-Flag_of_the_United_States.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/a/a4/Flag_of_the_United_States.svg/60px-Flag_of_the_United_States.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a class="mw-redirect" href="https://en.wikipedia.org/wiki/GDP_of_the_United_States" rel="mw:WikiLink" title="GDP of the United States">
#                United States
#               </a>
# </td>
# <td id="mwmg">
#               32,383,920
#              </td>
# <td id="mwmw">
#               30,769,700
#              </td>
# <td id="mwnA">
#               29,298,000
#              </td>
# </tr>
# <tr id="mwnQ">
# <td about="#mwt76" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"China"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}},"&lt;ref group=\"n\" name=\"China-THM\" /&gt; "]}' id="mwng" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_the_People's_Republic_of_China.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/40px-Flag_of_the_People%27s_Republic_of_China.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fa/Flag_of_the_People%27s_Republic_of_China.svg/60px-Flag_of_the_People%27s_Republic_of_China.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a class="mw-redirect" href="https://en.wikipedia.org/wiki/GDP_of_China" rel="mw:WikiLink" title="GDP of China">
#                China
#               </a>
# <sup about="#mwt77" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"group":"n","name":"China-THM"}}' id="cite_ref-China-THM_1-1" rel="dc:references" typeof="mw:Extension/ref">
# <a data-mw-group="n" href="#cite_note-China-THM-1" id="mwnw">
# <span class="mw-reflink-text" id="mwoA">
# <span class="cite-bracket" id="mwoQ">
#                   [
#                  </span>
#                  n 1
#                  <span class="cite-bracket" id="mwog">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </td>
# <td id="mwow">
#               20,851,593
#              </td>
# <td id="mwpA">
#               19,498,039
#              </td>
# <td id="mwpQ">
#               18,743,802
#              </td>
# </tr>
# <tr id="mwpg">
# <td about="#mwt78" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Germany"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="m

# %% [markdown]
# Separate the source names and their corresponding data.

# %% [markdown]
# Get the source names from the list of sources you have created.

# %%
sources = table.tbody.find_all('tr', recursive=False)[0]
sources.find_all("td")
print(sources.prettify())
# Out:
# <tr class="static-row-header" id="mwdw" style="text-align:center;">
#  <th id="mweA">
#   Country/Territory
#  </th>
#  <th id="mweQ" style="width:7.5em;">
#   <a href="https://en.wikipedia.org/wiki/International_Monetary_Fund" id="mweg" rel="mw:WikiLink" title="International Monetary Fund">
#    IMF
#   </a>
#   <br id="mwew"/>
#   (
#   <link about="#mwt61" data-mw='{"name":"section","attrs":{"begin":"IMF year"}}' id="mwfA" typeof="mw:Extension/section"/>
#   2026
#   <link about="#mwt62" data-mw='{"name":"section","attrs":{"end":"IMF year"}}' id="mwfQ" typeof="mw:Extension/section"/>
#   )
#   <sup about="#mwt65" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"IMFOCT2025"},"body":{"id":"mw-reference-text-cite_note-IMFOCT2025-2"}}' id="cite_ref-IMFOCT2025_2-1" rel="dc:references" typeof="mw:Extension/ref">
#    <a href="#cite_note-IMFOCT2025-2" id="mwfg">
#     <span class="mw-reflink-text" id="mwfw">
#      <span class="cite-bracket" id="mwgA">
#       [
#      </span>
#      1
#      <span class="cite-bracket" id="mwgQ">
#       ]
#      </span>
#     </span>
#    </a>
#   </sup>
#  </th>
#  <th id="mwgg" style="width:7.5em;">
#   <a class="mw-redirect" href="https://en.wikipedia.org/wiki/World_Bank" id="mwgw" rel="mw:WikiLink" title="World Bank">
#    World Bank
#   </a>
#   <br id="mwhA"/>
#   (2025)
#   <sup about="#mwt68" class="mw-ref reference" data-mw='{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-8"}}' id="cite_ref-8" rel="dc:references" typeof="mw:Extension/ref">
#    <a href="#cite_note-8" id="mwhQ">
#     <span class="mw-reflink-text" id="mwhg">
#      <span class="cite-bracket" id="mwhw">
#       [
#      </span>
#      6
#      <span class="cite-bracket" id="mwiA">
#       ]
#      </span>
#     </span>
#    </a>
#   </sup>
#  </th>
#  <th id="mwiQ" style="width:7.5em;">
#   <a href="https://en.wikipedia.org/wiki/United_Nations" id="mwig" rel="mw:WikiLink" title="United Nations">
#    United Nations
#   </a>
#   <br id="mwiw"/>
#   (2024)
#   <sup about="#mwt71" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"name":"UN"},"body":{"id":"mw-reference-text-cite_note-UN-9"}}' id="cite_ref-UN_9-0" rel="dc:references" typeof="mw:Extension/ref">
#    <a href="#cite_note-UN-9" id="mwjA">
#     <span class="mw-reflink-text" id="mwjQ">
#      <span class="cite-bracket" id="mwjg">
#       [
#      </span>
#      7
#      <span class="cite-bracket" id="mwjw">
#       ]
#      </span>
#     </span>
#    </a>
#   </sup>
#  </th>
# </tr>

# %% [markdown]
# Separate the header and data from the data that you separated before for the first source only, and then create a DataFrame using that.

# %%
table = soup.find_all("tr")
headers = table[0]
rows = table[100:]

headers = headers.find_all("th")
for th in headers:
    header_text = getText(th)

# %% [markdown]
# Repeat the last task for the other two data sources.

# %%
df = pd.DataFrame(index = [rows], columns = [headers])
df.head()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: [([
# , <td about="#mwt181" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Paraguay"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAog" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="660" data-file-type="drawing" data-file-width="1200" decoding="async" height="13" resource="https://en.wikipedia.org/wiki/File:Flag_of_Paraguay.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Paraguay.svg/40px-Flag_of_Paraguay.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/27/Flag_of_Paraguay.svg/60px-Flag_of_Paraguay.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Paraguay" rel="mw:WikiLink" title="Economy of Paraguay">
#                Paraguay
#               </a>
# </td>,
# , <td id="mwAok">
#               60,542
#              </td>,
# , <td id="mwAoo">
#               49,278
#              </td>,
# , <td id="mwAos">
#               44,739
#              </td>,
# ],), ([
# , <td about="#mwt182" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Zimbabwe"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAo0" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Zimbabwe.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Flag_of_Zimbabwe.svg/40px-Flag_of_Zimbabwe.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6a/Flag_of_Zimbabwe.svg/60px-Flag_of_Zimbabwe.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Zimbabwe" rel="mw:WikiLink" title="Economy of Zimbabwe">
#                Zimbabwe
#               </a>
# </td>,
# , <td id="mwAo4">
#               56,713
#              </td>,
# , <td id="mwAo8">
#               51,216
#              </td>,
# , <td id="mwApA">
#               45,719
#              </td>,
# ],), ([
# , <td about="#mwt183" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Macau"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}},"&lt;ref group=\"n\" name=\"Macau_China\" /&gt; "]}' id="mwApI" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Macau.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Flag_of_Macau.svg/40px-Flag_of_Macau.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/63/Flag_of_Macau.svg/60px-Flag_of_Macau.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Macau" rel="mw:WikiLink" title="Economy of Macau">
#                Macau
#               </a>
# <sup about="#mwt184" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"group":"n","name":"Macau_China"}}' id="cite_ref-Macau_China_14-0" rel="dc:references" typeof="mw:Extension/ref">
# <a data-mw-group="n" href="#cite_note-Macau_China-14" id="mwApM">
# <span class="mw-reflink-text" id="mwApQ">
# <span class="cite-bracket" id="mwApU">
#                   [
#                  </span>
#                  n 7
#                  <span class="cite-bracket" id="mwApY">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </td>,
# , <td id="mwApc">
#               54,228
#              </td>,
# , <td id="mwApg">
#               52,061
#              </td>,
# , <td id="mwApk">
#               49,467
#              </td>,
# ],), ([
# , <td about="#mwt185" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Latvia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAps" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Latvia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/84/Flag_of_Latvia.svg/40px-Flag_of_Latvia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/84/Flag_of_Latvia.svg/60px-Flag_of_Latvia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a class="mw-redirect" href="https://en.wikipedia.org/wiki/GDP_of_Latvia" rel="mw:WikiLink" title="GDP of Latvia">
#                Latvia
#               </a>
# </td>,
# , <td id="mwApw">
#               53,686
#              </td>,
# , <td id="mwAp0">
#               48,619
#              </td>,
# , <td id="mwAp4">
#               43,684
#              </td>,
# ],), ([
# , <td about="#mwt186" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Libya"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAqA" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="480" data-file-type="drawing" data-file-width="960" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Libya.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Libya.svg/40px-Flag_of_Libya.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/05/Flag_of_Libya.svg/60px-Flag_of_Libya.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Libya" rel="mw:WikiLink" title="Economy of Libya">
#                Libya
#               </a>
# </td>,
# , <td id="mwAqE">
#               52,453
#              </td>,
# , <td id="mwAqI">
#               48,099
#              </td>,
# , <td id="mwAqM">
#               48,484
#              </td>,
# ],), ([
# , <td about="#mwt187" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Cambodia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAqU" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="640" data-file-type="drawing" data-file-width="1000" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Cambodia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Flag_of_Cambodia.svg/40px-Flag_of_Cambodia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Flag_of_Cambodia.svg/60px-Flag_of_Cambodia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Cambodia" rel="mw:WikiLink" title="Economy of Cambodia">
#                Cambodia
#               </a>
# </td>,
# , <td id="mwAqY">
#               52,379
#              </td>,
# , <td id="mwAqc">
#               51,267
#              </td>,
# , <td id="mwAqg">
#               45,913
#              </td>,
# ],), ([
# , <td about="#mwt188" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Estonia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAqo" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="630" data-file-type="drawing" data-file-width="990" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Estonia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Flag_of_Estonia.svg/40px-Flag_of_Estonia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8f/Flag_of_Estonia.svg/60px-Flag_of_Estonia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Estonia" rel="mw:WikiLink" title="Economy of Estonia">
#                Estonia
#               </a>
# </td>,
# , <td id="mwAqs">
#               51,634
#              </td>,
# , <td id="mwAqw">
#               47,031
#              </td>,
# , <td id="mwAq0">
#               42,765
#              </td>,
# ],), ([
# , <td about="#mwt189" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Bahrain"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAq8" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1000" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Bahrain.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Bahrain.svg/40px-Flag_of_Bahrain.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2c/Flag_of_Bahrain.svg/60px-Flag_of_Bahrain.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Bahrain" rel="mw:WikiLink" title="Economy of Bahrain">
#                Bahrain
#               </a>
# </td>,
# , <td id="mwArA">
#               48,849
#              </td>,
# , <td id="mwArE">
#               48,966
#              </td>,
# , <td id="mwArI">
#               47,110
#              </td>,
# ],), ([
# , <td about="#mwt190" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Nepal"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwArQ" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="885" data-file-type="drawing" data-file-width="726" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Nepal.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Flag_of_Nepal.svg/20px-Flag_of_Nepal.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Flag_of_Nepal.svg/40px-Flag_of_Nepal.svg.png 2x" width="12"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Nepal" rel="mw:WikiLink" title="Economy of Nepal">
#                Nepal
#               </a>
# </td>,
# , <td id="mwArU">
#               45,844
#              </td>,
# , <td id="mwArY">
#               45,490
#              </td>,
# , <td id="mwArc">
#               42,692
#              </td>,
# ],), ([
# , <td about="#mwt191" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Cyprus"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}},"&lt;ref group=\"n\" name=\"Cyprus\" /&gt; "]}' id="mwArk" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="800" data-file-type="drawing" data-file-width="1200" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Cyprus.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Cyprus.svg/40px-Flag_of_Cyprus.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Cyprus.svg/60px-Flag_of_Cyprus.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Cyprus" rel="mw:WikiLink" title="Economy of Cyprus">
#                Cyprus
#               </a>
# <sup about="#mwt192" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"group":"n","name":"Cyprus"}}' id="cite_ref-Cyprus_15-0" rel="dc:references" typeof="mw:Extension/ref">
# <a data-mw-group="n" href="#cite_note-Cyprus-15" id="mwAro">
# <span class="mw-reflink-text" id="mwArs">
# <span class="cite-bracket" id="mwArw">
#                   [
#                  </span>
#                  n 8
#                  <span class="cite-bracket" id="mwAr0">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </td>,
# , <td id="mwAr4">
#               45,171
#              </td>,
# , <td id="mwAr8">
#               41,226
#              </td>,
# , <td id="mwAsA">
#               37,635
#              </td>,
# ],), ([
# , <td about="#mwt193" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Sudan"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAsI" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Sudan.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Sudan.svg/40px-Flag_of_Sudan.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Sudan.svg/60px-Flag_of_Sudan.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Sudan" rel="mw:WikiLink" title="Economy of Sudan">
#                Sudan
#               </a>
# </td>,
# , <td id="mwAsM">
#               44,688
#              </td>,
# , <td id="mwAsQ">
#               60,163
#              </td>,
# , <td id="mwAsU">
#               25,574
#              </td>,
# ],), ([
# , <td about="#mwt194" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Iceland"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAsc" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="900" data-file-type="drawing" data-file-width="1250" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Iceland.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_Iceland.svg/40px-Flag_of_Iceland.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/ce/Flag_of_Iceland.svg/60px-Flag_of_Iceland.svg.png 2x" width="21"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Iceland" rel="mw:WikiLink" title="Economy of Iceland">
#                Iceland
#               </a>
# </td>,
# , <td id="mwAsg">
#               43,800
#              </td>,
# , <td id="mwAsk">
#               38,583
#              </td>,
# , <td id="mwAso">
#               33,222
#              </td>,
# ],), ([
# , <td about="#mwt195" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Georgia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}},"&lt;ref group=\"n\" name=\"Georgia\" /&gt; "]}' id="mwAsw" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Georgia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Flag_of_Georgia.svg/40px-Flag_of_Georgia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0f/Flag_of_Georgia.svg/60px-Flag_of_Georgia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Georgia_(country)" rel="mw:WikiLink" title="Economy of Georgia (country)">
#                Georgia
#               </a>
# <sup about="#mwt196" class="mw-ref reference" data-mw='{"name":"ref","attrs":{"group":"n","name":"Georgia"}}' id="cite_ref-Georgia_16-0" rel="dc:references" typeof="mw:Extension/ref">
# <a data-mw-group="n" href="#cite_note-Georgia-16" id="mwAs0">
# <span class="mw-reflink-text" id="mwAs4">
# <span class="cite-bracket" id="mwAs8">
#                   [
#                  </span>
#                  n 9
#                  <span class="cite-bracket" id="mwAtA">
#                   ]
#                  </span>
# </span>
# </a>
# </sup>
# </td>,
# , <td id="mwAtE">
#               42,716
#              </td>,
# , <td id="mwAtI">
#               38,144
#              </td>,
# , <td id="mwAtM">
#               34,192
#              </td>,
# ],), ([
# , <td about="#mwt197" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Honduras"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAtU" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Honduras_(1949–2022,_2026–present).svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Honduras_%281949%E2%80%932022%2C_2026%E2%80%93present%29.svg/40px-Flag_of_Honduras_%281949%E2%80%932022%2C_2026%E2%80%93present%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/79/Flag_of_Honduras_%281949%E2%80%932022%2C_2026%E2%80%93present%29.svg/60px-Flag_of_Honduras_%281949%E2%80%932022%2C_2026%E2%80%93present%29.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Honduras" rel="mw:WikiLink" title="Economy of Honduras">
#                Honduras
#               </a>
# </td>,
# , <td id="mwAtY">
#               41,505
#              </td>,
# , <td id="mwAtc">
#               39,601
#              </td>,
# , <td id="mwAtg">
#               37,094
#              </td>,
# ],), ([
# , <td about="#mwt198" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Zambia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAto" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Zambia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Flag_of_Zambia.svg/40px-Flag_of_Zambia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Flag_of_Zambia.svg/60px-Flag_of_Zambia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Zambia" rel="mw:WikiLink" title="Economy of Zambia">
#                Zambia
#               </a>
# </td>,
# , <td id="mwAts">
#               41,243
#              </td>,
# , <td id="mwAtw">
#               28,880
#              </td>,
# , <td id="mwAt0">
#               25,303
#              </td>,
# ],), ([
# , <td about="#mwt199" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Senegal"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAt8" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Senegal.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Flag_of_Senegal.svg/40px-Flag_of_Senegal.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Flag_of_Senegal.svg/60px-Flag_of_Senegal.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Senegal" rel="mw:WikiLink" title="Economy of Senegal">
#                Senegal
#               </a>
# </td>,
# , <td id="mwAuA">
#               40,469
#              </td>,
# , <td id="mwAuE">
#               37,007
#              </td>,
# , <td id="mwAuI">
#               36,715
#              </td>,
# ],), ([
# , <td about="#mwt200" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"El Salvador"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAuQ" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="567" data-file-type="drawing" data-file-width="1005" decoding="async" height="13" resource="https://en.wikipedia.org/wiki/File:Flag_of_El_Salvador.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_El_Salvador.svg/40px-Flag_of_El_Salvador.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Flag_of_El_Salvador.svg/60px-Flag_of_El_Salvador.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_El_Salvador" rel="mw:WikiLink" title="Economy of El Salvador">
#                El Salvador
#               </a>
# </td>,
# , <td id="mwAuU">
#               39,838
#              </td>,
# , <td id="mwAuY">
#               36,708
#              </td>,
# , <td id="mwAuc">
#               35,365
#              </td>,
# ],), ([
# , <td about="#mwt201" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Haiti"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAuk" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1000" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Haiti.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/40px-Flag_of_Haiti.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/56/Flag_of_Haiti.svg/60px-Flag_of_Haiti.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Haiti" rel="mw:WikiLink" title="Economy of Haiti">
#                Haiti
#               </a>
# </td>,
# , <td id="mwAuo">
#               39,180
#              </td>,
# , <td id="mwAus">
#               32,077
#              </td>,
# , <td id="mwAuw">
#               25,312
#              </td>,
# ],), ([
# , <td about="#mwt202" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Bosnia and Herzegovina"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAu4" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="400" data-file-type="drawing" data-file-width="800" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Bosnia_and_Herzegovina.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Flag_of_Bosnia_and_Herzegovina.svg/40px-Flag_of_Bosnia_and_Herzegovina.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Flag_of_Bosnia_and_Herzegovina.svg/60px-Flag_of_Bosnia_and_Herzegovina.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Bosnia_and_Herzegovina" rel="mw:WikiLink" title="Economy of Bosnia and Herzegovina">
#                Bosnia and Herzegovina
#               </a>
# </td>,
# , <td id="mwAu8">
#               36,771
#              </td>,
# , <td id="mwAvA">
#               32,600
#              </td>,
# , <td id="mwAvE">
#               30,478
#              </td>,
# ],), ([
# , <td about="#mwt203" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Lebanon"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAvM" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="1920" data-file-type="drawing" data-file-width="2880" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Lebanon.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/40px-Flag_of_Lebanon.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Flag_of_Lebanon.svg/60px-Flag_of_Lebanon.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Lebanon" rel="mw:WikiLink" title="Economy of Lebanon">
#                Lebanon
#               </a>
# </td>,
# , <td id="mwAvQ">
#               34,497 (2025)
#              </td>,
# , <td id="mwAvU">
#               25,972 (2024)
#              </td>,
# , <td id="mwAvY">
#               37,990
#              </td>,
# ],), ([
# , <td about="#mwt204" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Papua New Guinea"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAvg" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="800" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Papua_New_Guinea.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Flag_of_Papua_New_Guinea.svg/20px-Flag_of_Papua_New_Guinea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Flag_of_Papua_New_Guinea.svg/40px-Flag_of_Papua_New_Guinea.svg.png 2x" width="20"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Papua_New_Guinea" rel="mw:WikiLink" title="Economy of Papua New Guinea">
#                Papua New Guinea
#               </a>
# </td>,
# , <td id="mwAvk">
#               34,403
#              </td>,
# , <td id="mwAvo">
#               32,499
#              </td>,
# , <td id="mwAvs">
#               32,262
#              </td>,
# ],), ([
# , <td about="#mwt205" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Guyana"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAv0" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1000" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Guyana.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/99/Flag_of_Guyana.svg/40px-Flag_of_Guyana.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/99/Flag_of_Guyana.svg/60px-Flag_of_Guyana.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Guyana" rel="mw:WikiLink" title="Economy of Guyana">
#                Guyana
#               </a>
# </td>,
# , <td id="mwAv4">
#               33,961
#              </td>,
# , <td id="mwAv8">
#               27,097
#              </td>,
# , <td id="mwAwA">
#               24,659
#              </td>,
# ],), ([
# , <td about="#mwt206" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Mali"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAwI" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Mali.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/92/Flag_of_Mali.svg/40px-Flag_of_Mali.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/92/Flag_of_Mali.svg/60px-Flag_of_Mali.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Mali" rel="mw:WikiLink" title="Economy of Mali">
#                Mali
#               </a>
# </td>,
# , <td id="mwAwM">
#               33,847
#              </td>,
# , <td id="mwAwQ">
#               30,069
#              </td>,
# , <td id="mwAwU">
#               26,588
#              </td>,
# ],), ([
# , <td about="#mwt207" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Albania"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAwc" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="500" data-file-type="drawing" data-file-width="700" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Albania.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/40px-Flag_of_Albania.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/36/Flag_of_Albania.svg/60px-Flag_of_Albania.svg.png 2x" width="21"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Albania" rel="mw:WikiLink" title="Economy of Albania">
#                Albania
#               </a>
# </td>,
# , <td id="mwAwg">
#               33,333
#              </td>,
# , <td id="mwAwk">
#               30,540
#              </td>,
# , <td id="mwAwo">
#               27,037
#              </td>,
# ],), ([
# , <td about="#mwt208" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Burkina Faso"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAww" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Burkina_Faso.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/31/Flag_of_Burkina_Faso.svg/40px-Flag_of_Burkina_Faso.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/31/Flag_of_Burkina_Faso.svg/60px-Flag_of_Burkina_Faso.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Burkina_Faso" rel="mw:WikiLink" title="Economy of Burkina Faso">
#                Burkina Faso
#               </a>
# </td>,
# , <td id="mwAw0">
#               32,513
#              </td>,
# , <td id="mwAw4">
#               27,627
#              </td>,
# , <td id="mwAw8">
#               23,250
#              </td>,
# ],), ([
# , <td about="#mwt209" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Armenia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAxE" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Armenia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/40px-Flag_of_Armenia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2f/Flag_of_Armenia.svg/60px-Flag_of_Armenia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Armenia" rel="mw:WikiLink" title="Economy of Armenia">
#                Armenia
#               </a>
# </td>,
# , <td id="mwAxI">
#               31,873
#              </td>,
# , <td id="mwAxM">
#               29,243
#              </td>,
# , <td id="mwAxQ">
#               25,955
#              </td>,
# ],), ([
# , <td about="#mwt210" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Malta"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAxY" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Malta.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Flag_of_Malta.svg/40px-Flag_of_Malta.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/73/Flag_of_Malta.svg/60px-Flag_of_Malta.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Malta" rel="mw:WikiLink" title="Economy of Malta">
#                Malta
#               </a>
# </td>,
# , <td id="mwAxc">
#               30,712
#              </td>,
# , <td id="mwAxg">
#               27,772
#              </td>,
# , <td id="mwAxk">
#               25,030
#              </td>,
# ],), ([
# , <td about="#mwt211" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Guinea"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAxs" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Guinea.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Flag_of_Guinea.svg/40px-Flag_of_Guinea.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Flag_of_Guinea.svg/60px-Flag_of_Guinea.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Guinea" rel="mw:WikiLink" title="Economy of Guinea">
#                Guinea
#               </a>
# </td>,
# , <td id="mwAxw">
#               29,930
#              </td>,
# , <td id="mwAx0">
#               28,346
#              </td>,
# , <td id="mwAx4">
#               36,465
#              </td>,
# ],), ([
# , <td about="#mwt212" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Mongolia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAyA" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Mongolia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Flag_of_Mongolia.svg/40px-Flag_of_Mongolia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Flag_of_Mongolia.svg/60px-Flag_of_Mongolia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Mongolia" rel="mw:WikiLink" title="Economy of Mongolia">
#                Mongolia
#               </a>
# </td>,
# , <td id="mwAyE">
#               28,450
#              </td>,
# , <td id="mwAyI">
#               25,369
#              </td>,
# , <td id="mwAyM">
#               23,586
#              </td>,
# ],), ([
# , <td about="#mwt213" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Benin"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAyU" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Benin.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Flag_of_Benin.svg/40px-Flag_of_Benin.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Flag_of_Benin.svg/60px-Flag_of_Benin.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Benin" rel="mw:WikiLink" title="Economy of Benin">
#                Benin
#               </a>
# </td>,
# , <td id="mwAyY">
#               27,786
#              </td>,
# , <td id="mwAyc">
#               24,566
#              </td>,
# , <td id="mwAyg">
#               21,483
#              </td>,
# ],), ([
# , <td about="#mwt214" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Trinidad and Tobago"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAyo" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="480" data-file-type="drawing" data-file-width="800" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Trinidad_and_Tobago.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Flag_of_Trinidad_and_Tobago.svg/40px-Flag_of_Trinidad_and_Tobago.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/64/Flag_of_Trinidad_and_Tobago.svg/60px-Flag_of_Trinidad_and_Tobago.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Trinidad_and_Tobago" rel="mw:WikiLink" title="Economy of Trinidad and Tobago">
#                Trinidad and Tobago
#               </a>
# </td>,
# , <td id="mwAys">
#               26,836
#              </td>,
# , <td id="mwAyw">
#               25,943
#              </td>,
# , <td id="mwAy0">
#               25,634
#              </td>,
# ],), ([
# , <td about="#mwt215" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Chad"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAy8" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Chad.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Flag_of_Chad.svg/40px-Flag_of_Chad.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4b/Flag_of_Chad.svg/60px-Flag_of_Chad.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Chad" rel="mw:WikiLink" title="Economy of Chad">
#                Chad
#               </a>
# </td>,
# , <td id="mwAzA">
#               25,628
#              </td>,
# , <td id="mwAzE">
#               21,473
#              </td>,
# , <td id="mwAzI">
#               19,797
#              </td>,
# ],), ([
# , <td about="#mwt216" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Niger"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAzQ" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="700" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Niger.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Flag_of_Niger.svg/20px-Flag_of_Niger.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Flag_of_Niger.svg/40px-Flag_of_Niger.svg.png 2x" width="18"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Niger" rel="mw:WikiLink" title="Economy of Niger">
#                Niger
#               </a>
# </td>,
# , <td id="mwAzU">
#               24,813
#              </td>,
# , <td id="mwAzY">
#               21,646
#              </td>,
# , <td id="mwAzc">
#               17,491
#              </td>,
# ],), ([
# , <td about="#mwt217" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Nicaragua"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAzk" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1000" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Nicaragua.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Nicaragua.svg/40px-Flag_of_Nicaragua.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/19/Flag_of_Nicaragua.svg/60px-Flag_of_Nicaragua.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Nicaragua" rel="mw:WikiLink" title="Economy of Nicaragua">
#                Nicaragua
#               </a>
# </td>,
# , <td id="mwAzo">
#               24,227
#              </td>,
# , <td id="mwAzs">
#               22,237
#              </td>,
# , <td id="mwAzw">
#               19,694
#              </td>,
# ],), ([
# , <td about="#mwt218" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Kyrgyzstan"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwAz4" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1000" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Kyrgyzstan.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Flag_of_Kyrgyzstan.svg/40px-Flag_of_Kyrgyzstan.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/Flag_of_Kyrgyzstan.svg/60px-Flag_of_Kyrgyzstan.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Kyrgyzstan" rel="mw:WikiLink" title="Economy of Kyrgyzstan">
#                Kyrgyzstan
#               </a>
# </td>,
# , <td id="mwAz8">
#               23,606
#              </td>,
# , <td id="mwA0A">
#               22,624
#              </td>,
# , <td id="mwA0E">
#               17,478
#              </td>,
# ],), ([
# , <td about="#mwt219" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Gabon"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwA0M" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# ...
#               3,327 (2023)
#              </td>,
# , <td id="mwBFs">
#               3,466
#              </td>,
# ],), ([
# , <td about="#mwt316" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Belize"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBF0" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1000" decoding="async" height="14" resource="https://en.wikipedia.org/wiki/File:Flag_of_Belize.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Flag_of_Belize.svg/40px-Flag_of_Belize.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Flag_of_Belize.svg/60px-Flag_of_Belize.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Belize" rel="mw:WikiLink" title="Economy of Belize">
#                Belize
#               </a>
# </td>,
# , <td id="mwBF4">
#               3,450
#              </td>,
# , <td id="mwBF8">
#               3,327
#              </td>,
# , <td id="mwBGA">
#               3,204
#              </td>,
# ],), ([
# , <td about="#mwt317" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Cape Verde"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBGI" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Cape_Verde.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_Cape_Verde_%283-2%29.svg/40px-Flag_of_Cape_Verde_%283-2%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/7a/Flag_of_Cape_Verde_%283-2%29.svg/60px-Flag_of_Cape_Verde_%283-2%29.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Cape_Verde" rel="mw:WikiLink" title="Economy of Cape Verde">
#                Cape Verde
#               </a>
# </td>,
# , <td id="mwBGM">
#               3,448
#              </td>,
# , <td id="mwBGQ">
#               3,057
#              </td>,
# , <td id="mwBGU">
#               2,768
#              </td>,
# ],), ([
# , <td about="#mwt318" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Guinea-Bissau"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBGc" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Guinea-Bissau.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Guinea-Bissau.svg/40px-Flag_of_Guinea-Bissau.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_Guinea-Bissau.svg/60px-Flag_of_Guinea-Bissau.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Guinea-Bissau" rel="mw:WikiLink" title="Economy of Guinea-Bissau">
#                Guinea-Bissau
#               </a>
# </td>,
# , <td id="mwBGg">
#               2,985
#              </td>,
# , <td id="mwBGk">
#               2,528
#              </td>,
# , <td id="mwBGo">
#               2,008
#              </td>,
# ],), ([
# , <td about="#mwt319" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Lesotho"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBGw" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Lesotho.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Flag_of_Lesotho.svg/40px-Flag_of_Lesotho.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4a/Flag_of_Lesotho.svg/60px-Flag_of_Lesotho.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Lesotho" rel="mw:WikiLink" title="Economy of Lesotho">
#                Lesotho
#               </a>
# </td>,
# , <td id="mwBG0">
#               2,972
#              </td>,
# , <td id="mwBG4">
#               2,574
#              </td>,
# , <td id="mwBG8">
#               2,391
#              </td>,
# ],), ([
# , <td about="#mwt320" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Gambia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBHE" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_The_Gambia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_The_Gambia.svg/40px-Flag_of_The_Gambia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Flag_of_The_Gambia.svg/60px-Flag_of_The_Gambia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a class="mw-redirect" href="https://en.wikipedia.org/wiki/Economy_of_The_Gambia" rel="mw:WikiLink" title="Economy of The Gambia">
#                Gambia
#               </a>
# </td>,
# , <td id="mwBHI">
#               2,792
#              </td>,
# , <td id="mwBHM">
#               2,594
#              </td>,
# , <td id="mwBHQ">
#               2,372
#              </td>,
# ],), ([
# , <td about="#mwt321" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Saint Lucia"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBHY" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Saint_Lucia.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Saint_Lucia.svg/40px-Flag_of_Saint_Lucia.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9f/Flag_of_Saint_Lucia.svg/60px-Flag_of_Saint_Lucia.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Saint_Lucia" rel="mw:WikiLink" title="Economy of Saint Lucia">
#                Saint Lucia
#               </a>
# </td>,
# , <td id="mwBHc">
#               2,765
#              </td>,
# , <td id="mwBHg">
#               2,656
#              </td>,
# , <td id="mwBHk">
#               2,574
#              </td>,
# ],), ([
# , <td about="#mwt322" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Zanzibar"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBHs" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="341" data-file-type="drawing" data-file-width="512" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Zanzibar.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Zanzibar.svg/40px-Flag_of_Zanzibar.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Flag_of_Zanzibar.svg/60px-Flag_of_Zanzibar.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a class="mw-redirect" href="https://en.wikipedia.org/wiki/Economy_of_Zanzibar" rel="mw:WikiLink" title="Economy of Zanzibar">
#                Zanzibar
#               </a>
# </td>,
# , <td about="#mwt323" class="table-na" data-mw='{"parts":["|| ",{"template":{"target":{"wt":"n/a","href":"./Template:N/a"},"params":{},"i":0}}," "]}' data-sort-value="" id="mwBHw" style="background: var(--background-color-interactive, #ececec); color: var(--color-base, inherit); vertical-align: middle; text-align: center; " typeof="mw:Transclusion">
# <span aria-hidden="true">
#                —
#               </span>
# <link about="#mwt324" data-mw='{"name":"templatestyles","attrs":{"src":"Screen reader-only/styles.css"}}' href="mw-data:TemplateStyles:r1152813436" rel="mw-deduplicated-inline-style" typeof="mw:Extension/templatestyles"/>
# <span class="sr-only">
#                N/a
#               </span>
# </td>,
# , <td about="#mwt325" class="table-na" data-mw='{"parts":["|| ",{"template":{"target":{"wt":"n/a","href":"./Template:N/a"},"params":{},"i":0}}," "]}' data-sort-value="" id="mwBH0" style="background: var(--background-color-interactive, #ececec); color: var(--color-base, inherit); vertical-align: middle; text-align: center; " typeof="mw:Transclusion">
# <span aria-hidden="true">
#                —
#               </span>
# <link about="#mwt326" data-mw='{"name":"templatestyles","attrs":{"src":"Screen reader-only/styles.css"}}' href="mw-data:TemplateStyles:r1152813436" rel="mw-deduplicated-inline-style" typeof="mw:Extension/templatestyles"/>
# <span class="sr-only">
#                N/a
#               </span>
# </td>,
# , <td id="mwBH4">
#               2,530
#              </td>,
# ],), ([
# , <td about="#mwt327" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"San Marino"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBIA" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="800" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_San_Marino.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/20px-Flag_of_San_Marino.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b1/Flag_of_San_Marino.svg/40px-Flag_of_San_Marino.svg.png 2x" width="20"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_San_Marino" rel="mw:WikiLink" title="Economy of San Marino">
#                San Marino
#               </a>
# </td>,
# , <td id="mwBIE">
#               2,417
#              </td>,
# , <td id="mwBII">
#               2,027 (2023)
#              </td>,
# , <td id="mwBIM">
#               2,082
#              </td>,
# ],), ([
# , <td about="#mwt328" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Antigua and Barbuda"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBIU" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="900" decoding="async" height="15" resource="https://en.wikipedia.org/wiki/File:Flag_of_Antigua_and_Barbuda.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/40px-Flag_of_Antigua_and_Barbuda.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/89/Flag_of_Antigua_and_Barbuda.svg/60px-Flag_of_Antigua_and_Barbuda.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Antigua_and_Barbuda" rel="mw:WikiLink" title="Economy of Antigua and Barbuda">
#                Antigua and Barbuda
#               </a>
# </td>,
# , <td id="mwBIY">
#               2,385
#              </td>,
# , <td id="mwBIc">
#               2,338
#              </td>,
# , <td id="mwBIg">
#               2,162
#              </td>,
# ],), ([
# , <td about="#mwt329" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"Seychelles"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBIo" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_Seychelles.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Seychelles.svg/40px-Flag_of_Seychelles.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Flag_of_Seychelles.svg/60px-Flag_of_Seychelles.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Seychelles" rel="mw:WikiLink" title="Economy of Seychelles">
#                Seychelles
#               </a>
# </td>,
# , <td id="mwBIs">
#               2,251
#              </td>,
# , <td id="mwBIw">
#               2,387
#              </td>,
# , <td id="mwBI0">
#               2,162
#              </td>,
# ],), ([
# , <td about="#mwt330" data-mw='{"parts":["| ",{"template":{"target":{"wt":"flagg","href":"./Template:Flagg"},"params":{"1":{"wt":"uspeft"},"2":{"wt":"East Timor"},"pref":{"wt":"GDP of"},"pref2":{"wt":"Economy of"}},"i":0}}," "]}' id="mwBI8" style="text-align:left" typeof="mw:Transclusion">
# <span class="nowrap">
# <span class="flagicon" style="display:inline-block;width:25px;text-align:left">
# <span class="mw-image-border" typeof="mw:File">
# <span>
# <img alt="" class="mw-file-element" data-file-height="600" data-file-type="drawing" data-file-width="1200" decoding="async" height="12" resource="https://en.wikipedia.org/wiki/File:Flag_of_East_Timor.svg" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/26/Flag_of_East_Timor.svg/40px-Flag_of_East_Timor.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/26/Flag_of_East_Timor.svg/60px-Flag_of_East_Timor.svg.png 2x" width="23"/>
# </span>
# </span>
# </span>
# <span typeof="mw:Entity">
# </span>
# </span>
# <a href="https://en.wikipedia.org/wiki/Economy_of_Timor-Leste" rel="mw:WikiLink" title="Economy of Timor-Leste">
#                Timor-Leste
#               </a>
# </td>,
# , <td id="mwBJA">
#               2,170
#              </td>,
# , <td id="mwBJE">
#               1,902
#              </td>,
# , <td id="mwBJI">
#               1,866
#              </td>,
# ],), ...]
#
# [174 rows x 0 columns]

# %%
from bs4 import BeautifulSoup

def html2table(file):
    file = f"{file}".strip()
        
    with open("./wiki.htm", "rb") as fd:
        soup = BeautifulSoup(fd)
        print(soup.prettify()[:1000])
    
    #3. Find the table structure you will need to deal with (how many tables are there?).
    
    table_structure = soup.find("table").prettify()
    #print(table_structure)
    
    #4. Find the right table using bs4.
    
    data_table = soup.find("table", {"class": '"wikitable"|}'})
    print(data_table.prettify()[:100])
    
    #5. Separate the source names and their corresponding data.
    
    sources = data_table.tbody.find_all("tr", recursive = False)[1].find_all("td", recursive = False)[0]
    sources_list = [td for td in sources.find_all("td")]
    
    #6. Get the source names from the list of sources you have created.
    
    sources_names = [sources.find_all("a")[0].getText() for source in sources_list]
    
    #7. Separate the header and data from the data that you separated before for the 
    #first source only, and then create a DataFrame using that.
    
    table = soup.find_all("tr")
    headers = table[0]
    rows = table[100:]
    header_text = [th.getText() for th in headers.find_all('th')]
    header_text
    
    df = pd.DataFrame(index = [rows], columns = [headers])
    df.head()
    print(df)



html2table(file = "./wiki.htm")

#8. Repeat the last task for the other two data sources.

html2table(file = "My Drive/github/MSDS/DSC 540 Data Preparation/Weeks 5 & 6/wikipedia_list_of_countries_by_gdp.html")
html2table(file = "My Drive/github/MSDS/DSC 540 Data Preparation/Weeks 5 & 6/worldometer.html")
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0064)https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal) -->
# <html class="client-js gr__en_wikipedia_org ve-not-available" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    List of countries by GDP (nominal) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_GDP_(nominal)","wgTitle":"List of countries by GDP (nominal)","wgCurRevisionId":861281423,"wgRevisionId":861281423,"wgArticleId":380845,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using Timeline","Wikipedia indefinitely semi-protected p
# <table class='"wikitable"|}' style="margin:auto; width:100%;">
#  <tbody>
#   <tr>
#    <td style="width:3
#                                                    [\n, [[<map name="timeline_45cabf722ffec5de02631bda1f6ccce0"></map>, <img src="./List of countries by GDP (nominal) - Wikipedia_files/45cabf722ffec5de02631bda1f6ccce0.png" usemap="#timeline_45cabf722ffec5de02631bda1f6ccce0"/>], \n]]
# [\n, [94], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [95], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [96], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [97], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [98], \n, [[<img alt="" class="thumbborder...                                                NaN
# ...                                                                                               ...
# [[[Wealth]], [[\n, <ul><li><a href="https://en....                                                NaN
# [[Other , [national accounts]], [[\n, <ul><li><...                                                NaN
# [[[Human development]], [[\n, <ul><li><a href="...                                                NaN
# [[[Digital divide]], [[\n, <ul><li><a href="htt...                                                NaN
# [[[Net international , <br/>,  investment posit...                                                NaN
#
# [532 rows x 1 columns]
# <!DOCTYPE html>
# <!-- saved from url=(0064)https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal) -->
# <html class="client-js gr__en_wikipedia_org ve-not-available" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    List of countries by GDP (nominal) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_GDP_(nominal)","wgTitle":"List of countries by GDP (nominal)","wgCurRevisionId":861281423,"wgRevisionId":861281423,"wgArticleId":380845,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using Timeline","Wikipedia indefinitely semi-protected p
# <table class='"wikitable"|}' style="margin:auto; width:100%;">
#  <tbody>
#   <tr>
#    <td style="width:3
#                                                    [\n, [[<map name="timeline_45cabf722ffec5de02631bda1f6ccce0"></map>, <img src="./List of countries by GDP (nominal) - Wikipedia_files/45cabf722ffec5de02631bda1f6ccce0.png" usemap="#timeline_45cabf722ffec5de02631bda1f6ccce0"/>], \n]]
# [\n, [94], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [95], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [96], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [97], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [98], \n, [[<img alt="" class="thumbborder...                                                NaN
# ...                                                                                               ...
# [[[Wealth]], [[\n, <ul><li><a href="https://en....                                                NaN
# [[Other , [national accounts]], [[\n, <ul><li><...                                                NaN
# [[[Human development]], [[\n, <ul><li><a href="...                                                NaN
# [[[Digital divide]], [[\n, <ul><li><a href="htt...                                                NaN
# [[[Net international , <br/>,  investment posit...                                                NaN
#
# [532 rows x 1 columns]
# <!DOCTYPE html>
# <!-- saved from url=(0064)https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal) -->
# <html class="client-js gr__en_wikipedia_org ve-not-available" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    List of countries by GDP (nominal) - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
#   </script>
#   <script>
#    (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_by_GDP_(nominal)","wgTitle":"List of countries by GDP (nominal)","wgCurRevisionId":861281423,"wgRevisionId":861281423,"wgArticleId":380845,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Pages using Timeline","Wikipedia indefinitely semi-protected p
# <table class='"wikitable"|}' style="margin:auto; width:100%;">
#  <tbody>
#   <tr>
#    <td style="width:3
#                                                    [\n, [[<map name="timeline_45cabf722ffec5de02631bda1f6ccce0"></map>, <img src="./List of countries by GDP (nominal) - Wikipedia_files/45cabf722ffec5de02631bda1f6ccce0.png" usemap="#timeline_45cabf722ffec5de02631bda1f6ccce0"/>], \n]]
# [\n, [94], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [95], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [96], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [97], \n, [[<img alt="" class="thumbborder...                                                NaN
# [\n, [98], \n, [[<img alt="" class="thumbborder...                                                NaN
# ...                                                                                               ...
# [[[Wealth]], [[\n, <ul><li><a href="https://en....                                                NaN
# [[Other , [national accounts]], [[\n, <ul><li><...                                                NaN
# [[[Human development]], [[\n, <ul><li><a href="...                                                NaN
# [[[Digital divide]], [[\n, <ul><li><a href="htt...                                                NaN
# [[[Net international , <br/>,  investment posit...                                                NaN
#
# [532 rows x 1 columns]
