# %%
# custom function to write html section titles and descriptions

def html(level, title, description):
    import ipywidgets as widgets
    from IPython.display import display, HTML
    display(HTML(f"""
    <a id="{title.lower().replace(" ", "-")}"></a>
    <h{level} align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">{title}</h{level}>
    <div align = "center">
    <h{level-2} align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">{description}</h{level-2}>
    </div>
    """))

# %%
html(1, "Graph Analysis with Matplotlib", "Week 2")
# Out:
#     <a id="graph-analysis-with-matplotlib"></a>
#     <h1 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Graph Analysis with Matplotlib</h1>
#     <div align = "center">
#     <h-1 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Week 2</h-1>
#     </div>

# %% [markdown]
# - [x] Complete several of the Matplotlib tutorials at the following link until you feel comfortable: Matplotlib Tutorials.
# - [x] Using a data set of your choice, write an introduction explaining the data set.
# - [x] Identify a question or question(s) that you would like to explore in your data set.
# - [x] Create at least three graphs that help answer these questions. Make sure your graphs are clearly readable and are labeled appropriately and professionally.
# - [ ] Explain what you have learned from each of your graphs.
# - [ ] Write a conclusion that summarizes your findings.

# %%
html(1, "Matplotlib tutorials", "")
# Out:
#     <a id="matplotlib-tutorials"></a>
#     <h1 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Matplotlib tutorials</h1>
#     <div align = "center">
#     <h-1 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;"></h-1>
#     </div>

# %%
import sys

modules = """
pandas
matplotlib
openpyxl
forestplot
"""

with open("./requirements.txt", "w") as f:
    f.write(modules)

# !{sys.executable} -m pip install -r requirements.txt
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in C:\Python314\Lib\site-packages (from -r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: matplotlib in C:\Python314\Lib\site-packages (from -r requirements.txt (line 3)) (3.11.0)
# Requirement already satisfied: openpyxl in C:\Python314\Lib\site-packages (from -r requirements.txt (line 4)) (3.1.5)
# Requirement already satisfied: forestplot in C:\Python314\Lib\site-packages (from -r requirements.txt (line 5)) (0.4.1)
# Requirement already satisfied: numpy>=2.3.3 in C:\Python314\Lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Python314\Lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Python314\Lib\site-packages (from pandas->-r requirements.txt (line 2)) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Python314\Lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: et-xmlfile in C:\Python314\Lib\site-packages (from openpyxl->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: matplotlib-inline<=0.1.3 in C:\Python314\Lib\site-packages (from forestplot->-r requirements.txt (line 5)) (0.1.3)
# Requirement already satisfied: traitlets in C:\Python314\Lib\site-packages (from matplotlib-inline<=0.1.3->forestplot->-r requirements.txt (line 5)) (5.15.1)
# Requirement already satisfied: six>=1.5 in C:\Python314\Lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)

# %%
html(2, "Line plots", "")
# Out:
#     <a id="line-plots"></a>
#     <h2 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Line plots</h2>
#     <div align = "center">
#     <h0 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;"></h0>
#     </div>

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]
plt.plot(x, y)
plt.axis([0, 4, 0, 16])
plt.ylabel("Y-axis label")
plt.show()

# %%
html(2, "Plot", "")
# Out:
#     <a id="plot"></a>
#     <h2 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Plot</h2>
#     <div align = "center">
#     <h0 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;"></h0>
#     </div>

# %%
import numpy as np

t = np.arange(0., 5., 0.2)
plt.plot(t, t, "r--", t, t**2, "bs", t, t**3, "g^")
plt.show()

# %%
html(2, "Scatter Plots", "")
# Out:
#     <a id="scatter-plots"></a>
#     <h2 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Scatter Plots</h2>
#     <div align = "center">
#     <h0 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;"></h0>
#     </div>

# %%
import pandas as pd
a = np.random.randint(1, 100, size = 10)
b = np.random.randint(1, 100, size = 10)
c = np.random.randint(1, 100, 10)
d = np.random.randint(1, 100, 10)
data = pd.DataFrame({
    "a": a,
    "b": b,
    "c": c, 
    "d": d})
plt.scatter(x = [1, 2, 3, 4], y = [2, 4, 9, 16], s = 1, c = "black", data = data)
plt.show()

# %%
html(2, "Subplots", "")
# Out:
#     <a id="subplots"></a>
#     <h2 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;">Subplots</h2>
#     <div align = "center">
#     <h0 align = "center"; style = "font-family:Times New Roman; font-variant:small-caps;"></h0>
#     </div>

# %%
import pandas as pd

def csv(file):
    df = pd.read_csv(file, encoding = "utf-8")
    return df

def excel(file):
    df = pd.read_excel(file)
    return df

# %% [markdown]
# **1. Using a data set of your choice, write an introduction explaining the data set.**

# %%
data = csv("./data/data.csv")
data.head()
# Out:
#     ID                   Study                     Study design  LOE      N  \
# 0  1.0  Akoto and Hoeher, 2012         Prospective cohort study   II   87.0
# 1  2.0      Akoto et al., 2015    Prospective comparative study   II   10.0
# 2  3.0      Akoto et al., 2019  Retrospective comparative study  III   41.0
# 3  4.0      Aslam et al., 2021  Retrospective comparative study  III   35.0
# 4  5.0      Barié et al., 2010         Prospective cohort study   II  106.0
#
#      M/F  Male  Female  Age (years)   Age  ...  KOOS symptoms  KOOS QoL  \
# 0  75/12  75.0    12.0     31 ± 7.6  31.0  ...            NaN       NaN
# 1   10/0  10.0     0.0  27.4 ± 10.7  27.4  ...            NaN       NaN
# 2   32/9  32.0     9.0      29 ± 10  29.0  ...            NaN       NaN
# 3  19/11  19.0    11.0   24.6 ± 3.3  24.6  ...            NaN       NaN
# 4  63/43  63.0    43.0     30 ± 5.4  30.0  ...            NaN       NaN
#
#   Pivot shift Instrumental laxity  VAS Graft rupture Donor site morbidity  \
# 0           ✓                   ✓  NaN             ✓                    ✓
# 1           ✓                   ✓  NaN           NaN                  NaN
# 2           ✓                   ✓  NaN             ✓                    ✓
# 3         NaN                 NaN  NaN             ✓                  NaN
# 4           ✓                   ✓  NaN             ✓                    ✓
#
#   Arthrofibrosis SLHT Patellar fracture
# 0            NaN    ✓               NaN
# 1            NaN  NaN               NaN
# 2            NaN    ✓               NaN
# 3            NaN  NaN               NaN
# 4              ✓  NaN               NaN
#
# [5 rows x 44 columns]

# %%
outcomes = {"IKDC subjective": "ikdc_subjective",
"Lysholm": "lysholm",
"Tegner": "tegner",
"Instrumental laxity": "instrumental_laxity",
"Pivot shift": "pivot_shift",
"Lachman": "lachman",
"Graft rupture": "graft_rupture"}

# covariates dataset merge with sheets for analysis
for x, y in outcomes.items():
    df = csv("./data/data.csv")
    cov = df[df[x] == "✓"]
    cov = cov[["ID", "Study", "Age", "Follow-up", "M/F"]]
    analysis = csv(f"./data/{y}.csv")  
    cov["ID"] = cov.set_index
    analysis["id"] = analysis.set_index
    data = analysis.merge(right = cov, how = "outer", on = cov["ID"])
    globals()[f"{y}"] = data

# %% [markdown]
# These datasets are data extracted from studies that reported the specific outcome in patients who had undergone surgery using either one of two surgical techniques.
#
# IKDC subjective knee form, Lysholm knee scoring scale, and Tegner activity scale are patient-reported outcome measures (PROMs) that are used to evaluate the patients' quality of life. It is frequently used before and after the surgery, with various follow-up durations (time after surgery) to see if there is an improvement in the patients' overall wellbeing and knee function in relation to daily living compared to baseline.
#
# Instrumental laxity, pivot shift test and Lachman test are objective measures of knee stability. Instrumental laxity and Lachman measure anteroposterior (AP) translational stability while pivot shift measures rotational stability of the knee. Instrumental laxity dataset contains continuous data in millimeters of the side-to-side difference in AP translation (how much the tibia and femur move in relation to each other) compared with the healthy knee. Pivot shift and Lachman are graded categorically with 4 levels in both tests.
#
# Graft rupture is a dataset containing binary data or categorical data with only two levels.

# %% [markdown]
# **2. Identify a question or question(s) that you would like to explore in your data set.**

# %% [markdown]
# Does follow up duration, mean age, and gender of the patients have an effect on the visual representations of the effect sizes? In order to explore this research question, follow up duration, mean age and gender of the patients were included in a dataset from a previous project to plot the data points separately by binning the covariates into subsets.

# %% [markdown]
# **3. Create at least three graphs that help answer these questions.
#      Make sure your graphs are clearly readable and are labeled appropriately and professionally.**

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import scatter

outcomes = {
    "IKDC Subjective": ikdc_subjective, 
    "Lysholm Knee Scoring Scale": lysholm, 
    "Tegner Activity Scale": tegner, 
    "Instrumental laxity": instrumental_laxity, 
    "Pivot shift": pivot_shift, 
    "Lachman": lachman, 
    "Graft rupture": graft_rupture
}

# %%
# !pip install forestplot
# Out:
# Requirement already satisfied: forestplot in G:\My Drive\.venv\Lib\site-packages (0.4.1)
# Requirement already satisfied: pandas in G:\My Drive\.venv\Lib\site-packages (from forestplot) (3.0.3)
# Requirement already satisfied: numpy in G:\My Drive\.venv\Lib\site-packages (from forestplot) (2.4.6)
# Requirement already satisfied: matplotlib in G:\My Drive\.venv\Lib\site-packages (from forestplot) (3.11.0)
# Requirement already satisfied: matplotlib-inline<=0.1.3 in G:\My Drive\.venv\Lib\site-packages (from forestplot) (0.1.3)
# Requirement already satisfied: traitlets in G:\My Drive\.venv\Lib\site-packages (from matplotlib-inline<=0.1.3->forestplot) (5.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (26.2)
# Requirement already satisfied: pillow>=9 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in G:\My Drive\.venv\Lib\site-packages (from matplotlib->forestplot) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in G:\My Drive\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->forestplot) (1.17.0)
# Requirement already satisfied: tzdata in G:\My Drive\.venv\Lib\site-packages (from pandas->forestplot) (2026.2)

# %%
import forestplot as fp
import pandas as pd
df = csv("./data/data.csv")
data = pd.read_excel("./data/outcome.xlsx")
df = df.fillna("")
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       1 import forestplot as fp
#       2 import pandas as pd
#       3 df = csv("./data/data.csv")
# ----> 4 data = pd.read_excel("./data/outcome.xlsx")
#       5 df = df.fillna("")
#       6 data.head()
#
# File C:\Python314\Lib\site-packages\pandas\io\excel\_base.py:494, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#     493 try:
# --> 494     data = io.parse(
#     495         sheet_name=sheet_name,
#     496         header=header,
#     497         names=names,
#     498         index_col=index_col,
#     499         usecols=usecols,
#     500         dtype=dtype,
#     501         converters=converters,
#     502         true_values=true_values,
#     503         false_values=false_values,
#     504         skiprows=skiprows,
#     505         nrows=nrows,
#     506         na_values=na_values,
#     507         keep_default_na=keep_default_na,
#     508         na_filter=na_filter,
#     509         verbose=verbose,
#     510         parse_dates=parse_dates,
#     511         date_format=date_format,
#     512         thousands=thousands,
#     513         decimal=decimal,
#     514         comment=comment,
#     515         skipfooter=skipfooter,
#     516         dtype_backend=dtype_backend,
#     517     )
#     518 finally:
#     519     # make sure to close opened file handles
#     520     if should_close:
#
# File C:\Python314\Lib\site-packages\pandas\io\excel\_base.py:1780, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1630 def parse(
#    1631     self,
#    1632     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)   1649     **kwds,
#    1650 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1651     """
#    1652     Parse specified sheet(s) into a DataFrame.
#    1653
#    (...)   1778     >>> file.parse()  # doctest: +SKIP
#    1779     """
# -> 1780     return self._reader.parse(
#    1781         sheet_name=sheet_name,
#    1782         header=header,
#    1783         names=names,
#    1784         index_col=index_col,
#    1785         usecols=usecols,
#    1786         converters=converters,
#    1787         true_values=true_values,
#    1788         false_values=false_values,
#    1789         skiprows=skiprows,
#    1790         nrows=nrows,
#    1791         na_values=na_values,
#    1792         parse_dates=parse_dates,
#    1793         date_format=date_format,
#    1794         thousands=thousands,
#    1795         comment=comment,
#    1796         skipfooter=skipfooter,
#    1797         dtype_backend=dtype_backend,
#    1798         **kwds,
#    1799     )
#
# File C:\Python314\Lib\site-packages\pandas\io\excel\_base.py:758, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     755     sheet = self.get_sheet_by_index(asheetname)
#     757 file_rows_needed = self._calc_rows(header, index_col, skiprows, nrows)
# --> 758 data = self.get_sheet_data(sheet, file_rows_needed)
#     759 if hasattr(sheet, "close"):
#     760     # pyxlsb opens two TemporaryFiles
#     761     sheet.close()
#
# File C:\Python314\Lib\site-packages\pandas\io\excel\_openpyxl.py:622, in OpenpyxlReader.get_sheet_data(self, sheet, file_rows_needed)
#     620 data: list[list[Scalar]] = []
#     621 last_row_with_data = -1
# --> 622 for row_number, row in enumerate(sheet.rows):
#     623     converted_row = [self._convert_cell(cell) for cell in row]
#     624     while converted_row and converted_row[-1] == "":
#     625         # trim trailing empty elements
#
# File C:\Python314\Lib\site-packages\openpyxl\worksheet\_read_only.py:85, in ReadOnlyWorksheet._cells_by_row(self, min_col, min_row, max_col, max_row, values_only)
#      77 with self._get_source() as src:
#      78     parser = WorkSheetParser(src,
#      79                              self._shared_strings,
#      80                              data_only=self.parent.data_only,
#      81                              epoch=self.parent.epoch,
#      82                              date_formats=self.parent._date_formats,
#      83                              timedelta_formats=self.parent._timedelta_formats)
# ---> 85     for idx, row in parser.parse():
#      86         if max_row is not None and idx > max_row:
#      87             break
#
# File C:\Python314\Lib\site-packages\openpyxl\worksheet\_reader.py:167, in WorkSheetParser.parse(self)
#     165     element.clear()
#     166 elif tag_name == ROW_TAG:
# --> 167     row = self.parse_row(element)
#     168     element.clear()
#     169     yield row
#
# File C:\Python314\Lib\site-packages\openpyxl\worksheet\_reader.py:303, in WorkSheetParser.parse_row(self, row)
#     299 if keys - {'r', 'spans'}:
#     300     # don't create dimension objects unless they have relevant information
#     301     self.row_dimensions[str(self.row_counter)] = attrs
# --> 303 cells = [self.parse_cell(el) for el in row]
#     304 return self.row_counter, cells
#
# File C:\Python314\Lib\site-packages\openpyxl\worksheet\_reader.py:227, in WorkSheetParser.parse_cell(self, element)
#     225             value = "#VALUE!"
#     226 elif data_type == 's':
# --> 227     value = self.shared_strings[int(value)]
#     228 elif data_type == 'b':
#     229     value = bool(int(value))
#
# ValueError: invalid literal for int() with base 10: '5.3'

# %%
ikdc_plot = fp.forestplot(
        dataframe = data,
        estimate = "yi",
        ll = "ci.lb",
        hl = "ci.ub",
        varlabel = "study",
        xlabel = "IKDC Subjective",
        ylabel = "Studies"
)

ikdc_plot

# %%
df = ikdc_subjective

S = df[df["graft_type"] == "S-QT"]
B = df[df["graft_type"] == "B-QT"]

plt.plot(S["yi"]/100, "b--") # S-QT
plt.plot(B["yi"]/100, "r--") # B-QT
plt.show()

# %%
df = tegner

S = df[df["graft_type"] == "S-QT"] 
B = df[df["graft_type"] == "B-QT"]

plt.plot(S["yi"]/100, "b--") # S-QT
plt.plot(B["yi"]/100, "r--") # B-QT
plt.show()

# %%
df = lysholm

S = df[df["graft_type"] == "S-QT"] 
B = df[df["graft_type"] == "B-QT"]

plt.plot(S["yi"]/100, "b--") # S-QT
plt.plot(B["yi"]/100, "r--") # B-QT

plt.show()

# %%
df = pivot_shift

S = df[df["graft_type"] == "S-QT"] 
B = df[df["graft_type"] == "B-QT"]


plt.plot(S["yi"]/100, "b--") # S-QT
plt.plot(B["yi"]/100, "r--") # B-QT
plt.show()

# %%
df = lachman

S = df[df["graft_type"] == "S-QT"] 
B = df[df["graft_type"] == "B-QT"]

plt.plot(S["yi"]/100, "b--") # S-QT
plt.plot(B["yi"]/100, "r--") # B-QT
plt.show()

# %%
df = instrumental_laxity

S = df[df["graft_type"] == "S-QT"] 
B = df[df["graft_type"] == "B-QT"]


plt.plot(S["yi"]/100, "b--") # S-QT
plt.plot(B["yi"]/100, "r--") # B-QT
plt.show()

# %%
df = graft_rupture

S = df[df["graft_type"] == "S-QT"] 
B = df[df["graft_type"] == "B-QT"]


plt.plot(S["yi"], "b--") # S-QT
plt.plot(B["yi"], "r--") # B-QT
plt.show()

# %% [markdown]
# 1. In the IKDC subjective knee form dataset, B-QT definitely has data points with higher values and less dispersion than those of the S-QT subgroup.
# 2. In Lysholm dataset, the S-QT subgroup appears to have more overall dispersion than the B-QT subgroup.
# 3. In the Tegner dataset, the S-QT subgroup

# %% [markdown]
# **5. Write a conclusion that summarizes your findings.**

# %% [markdown]
# The conclusion obtained for IKDC Subjective, Lysholm, and Tegner Activity
