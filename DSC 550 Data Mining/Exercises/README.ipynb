# %%
# !jupyter book init --write-toc
# Out:
# building myst-cli session with API URL: https://api.mystmd.org
# âœ… Project already initialized with config file: myst.yml
# âœ… Site already initialized with config file: myst.yml
# (node:15168) ExperimentalWarning: localStorage is not available because --localstorage-file was not provided.
# (Use `node --trace-warnings ...` to show where the warning was created)
# Not writing the table of contents, it already exists!

# %%
# !jupyter book init
# !jupyter book init --write-toc
# !jupyter book start
