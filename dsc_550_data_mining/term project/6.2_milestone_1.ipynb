# %% [markdown]
# Dong Woon Kim, M.D.
# BRUIN ID: 21399491
#
# Bellevue University
# Masters in Data Science
# DSC 550 Data Mining

# %% [markdown]
# ## Term Project Milestone 1

# %% [markdown]
# **Problem**:
#
# The World Health Organization (WHO) published a statement that implored the use of the best available scientific or research evidence even over a physician's own opinion gained through their clinical experience to implement clinical decisions to improve patient outcomes[^1]. The Oxford Centre for Evidence-Based Medicine (CEBM) has stated that systematic reviews of randomized controlled trials are the best available evidence [^1],[^2].
#
# Despite the importance systematic reviews and meta-analyses are supposed to play in the field of medicine, there is a lack of consistency and quality in these types of studies available for physicians in the literature databases, exacerbated by the inefficiency by which they are completed, with the average time for completing and publishing systematic reviews from start to finish for research teams being 11.5 months and 16.2 months, respectively[^3]. Currently, most teams are still performing systematic reviews manually, with excel spreadsheets and printed full-text PDFs.
#
# | category   |   mean |    sd |   median |   iqr |   min |    max |
# |:-----------|-------:|------:|---------:|------:|------:|-------:|
# | authors    |   5    |  3    |     5    |   3   |     1 |  27    |
# | time       |  67.3  | 31    |    65.8  |  41.6 |     6 | 186    |
# | yield      |   2.94 |  6.49 |     0.93 |   2.5 |     0 |  64.71 |
#
# ![fig_1a](./figures/fig_1a.png)
# ![fig_1b](./figures/fig_1b.png)
#
#
# | category   |   time |   authors |
# |:-----------|-------:|----------:|
# | funded     |     42 |       6.8 |
# | not funded |     26 |       4.8 |
#
# ![fig_2|30](./figures/fig_2.png)
#
#
# On the other hand, research teams and software companies have developed automation tools to shorten the amount of time it takes to complete these systematic review papers. In fact, one team has published an award-winning article that outlines how a systematic review paper was and can be completed in 2 weeks. However, the software and tools they used are largely inaccessible to the average researcher, produce inconsistent and inaccurate results. Furthermore, much of these automation tools rely on artificial intelligence, which do not have the intuition and sense that is required to bridge the evidence together with a practical solution to be applied. Research is filling in gaps of knowledge with new data, while artificial intelligence is designed to summarize what has already been filled with old data.
#
# | task                         |   hours |
# |:-----------------------------|--------:|
# | find previous or upcoming SR |      63 |
# | deduplication                |      16 |
# | protocol                     |     175 |
# | search strategy              |     109 |
# | search                       |      72 |
# | title abstract screening     |     404 |
# | pdf                          |      41 |
# | full-text screening          |     187 |
# | trial registries screening   |     123 |
# | citation screening           |     201 |
# | forms                        |      72 |
# | extraction                   |     461 |
# | risk of bias                 |     323 |
# | meta-analysis                |     167 |
# | manuscript                   |     428 |
#
# Therefore, I wanted to find a solution that meets these two somewhere in the middle. A ***system*** for conducting ***systematic*** reviews, where the user inputs dictate every nuance of automation, which does not rely on third party or artificial intelligence.
#
# ![fig_3](./figures/fig_3.png)
#
# <!---
# If someone wants to know if drinking milk really does make your bones stronger or not, then they should be able to find not only the best source of evidence, but all of it at once, which is combined into one dataset that is summarized in a forest plot that clearly shows the statistical analysis results not only numerically but also in a visually-appealing and informative way.
# -->

# %% [markdown]
# **Code used to generate tables and figures**:

# %% [markdown]
# **Table 1**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df1 = pd.DataFrame({
    "category": ["funded", "not funded"],
    "time": [42, 26],
    "authors": [6.8, 4.8]})

# %%
df1.head()
# Out:
#      category  time  authors
# 0      funded    42      6.8
# 1  not funded    26      4.8

# %% [markdown]
# **Figure 1**

# %%
plt.figure(figsize=(5,4))

plt.bar(df1["category"], df1["time"])

plt.ylabel("Time")
plt.xlabel("Funding")
plt.title("Average Project Time")
plt.savefig("./Exercises/figures/fig_1a.png", dpi=300)
plt.show()

plt.figure(figsize=(5,4))

plt.bar(df1["category"], df1["authors"])

plt.ylabel("Authors")
plt.xlabel("Funding")
plt.title("Average Number of Authors")
plt.savefig("./Exercises/figures/fig_1b.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       4
#       5 plt.ylabel("Time")
#       6 plt.xlabel("Funding")
#       7 plt.title("Average Project Time")
# ----> 8 plt.savefig("./Exercises/figures/fig_1a.png", dpi=300)
#       9 plt.show()
#      10
#      11 plt.figure(figsize=(5,4))
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\pyplot.py:1346, in savefig(fname, **kwargs)
#    1343 fig = gcf()
#    1344 # savefig default implementation has no return, so mypy is unhappy
#    1345 # presumably this is here because subclasses can return?
# -> 1346 res = fig.savefig(fname, **kwargs)  # type: ignore[func-returns-value]
#    1347 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1348 return res
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\figure.py:3515, in Figure.savefig(self, fname, transparent, **kwargs)
#    3513     for ax in self.axes:
#    3514         _recursively_make_axes_transparent(stack, ax)
# -> 3515 self.canvas.print_figure(fname, **kwargs)
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\backend_bases.py:2289, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2285 try:
#    2286     # _get_renderer may change the figure dpi (as vector formats
#    2287     # force the figure dpi to 72), so we need to set it again here.
#    2288     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2289         result = print_method(
#    2290             filename,
#    2291             facecolor=facecolor,
#    2292             edgecolor=edgecolor,
#    2293             orientation=orientation,
#    2294             bbox_inches_restore=_bbox_inches_restore,
#    2295             **kwargs)
#    2296 finally:
#    2297     if bbox_inches and restore_bbox:
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\backend_bases.py:2146, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2142     optional_kws = {  # Passed by print_figure for other renderers.
#    2143         "dpi", "facecolor", "edgecolor", "orientation",
#    2144         "bbox_inches_restore"}
#    2145     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2146     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2147         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2148 else:  # Let third-parties do as they see fit.
#    2149     print_method = meth
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\backends\backend_agg.py:537, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     490 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     491     """
#     492     Write the figure to a PNG file.
#     493
#    (...)    535         *metadata*, including the default 'Software' key.
#     536     """
# --> 537     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\backends\backend_agg.py:486, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     481 """
#     482 Draw the canvas, then save it using `.image.imsave` (to which
#     483 *pil_kwargs* and *metadata* are forwarded).
#     484 """
#     485 FigureCanvasAgg.draw(self)
# --> 486 mpl.image.imsave(
#     487     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     488     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\matplotlib\image.py:1722, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1720 pil_kwargs.setdefault("format", format)
#    1721 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1722 image.save(fname, **pil_kwargs)
#
# File G:\My Drive\github\d-wkim\.venv\Lib\site-packages\PIL\Image.py:2706, in Image.save(self, fp, format, **params)
#    2704         fp = builtins.open(filename, "r+b")
#    2705     else:
# -> 2706         fp = builtins.open(filename, "w+b")
#    2707 else:
#    2708     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Exercises/figures/fig_1a.png'

# %% [markdown]
# **Table 2**

# %%
df2 = pd.DataFrame(np.array([
        ["authors", 5, 3, 5, 3, 1, 27],
        ["time", 67.3, 31, 65.8, 41.6, 6, 186],
        ["yield", 2.94, 6.49, 0.93, 2.5, 0, 64.71]]),
        columns = ["category", "mean", "sd", "median", "iqr", "min", "max"]
)

# %%
df2.head()
from IPython.display import display, Markdown, HTML
display(Markdown(df2.to_markdown(index = False)))

print(df1.to_markdown(index = False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df2.head()
#       2 from IPython.display import display, Markdown, HTML
#       3 display(Markdown(df2.to_markdown(index = False)))
#       4
#
# NameError: name 'df2' is not defined

# %% [markdown]
# **Figure 2**

# %%
plt.figure(figsize=(5,4))

plt.bar(
    df2["category"],
    df2["mean"],
    yerr=df2["sd"],
    capsize=5
)

plt.ylabel("Mean ± SD")
plt.xlabel("Category")
plt.title("Summary Statistics")
plt.savefig("./Exercises/figures/fig_2.png", dpi=300)
plt.show()

# %%
df3 = pd.DataFrame(np.array([
        ["find previous or upcoming SR", 63],
        ["deduplication", 16],
        ["protocol", 175],
        ["search strategy", 109],
        ["search", 72],
        ["title abstract screening", 404],
        ["pdf", 41],
        ["full-text screening", 187],
        ["trial registries screening", 123],
        ["citation screening", 201],
        ["forms", 72],
        ["extraction", 461],
        ["risk of bias", 323],
        ["meta-analysis", 167],
        ["manuscript", 428]]),
        columns = ["task", "hours"])

#df3_sorted = df3.sort_values("hours", ascending=False)

plt.bar(df3_sorted["task"], df3_sorted["hours"])

plt.xticks(rotation=90)
plt.ylabel("Hours")
plt.xlabel("Task")
plt.title("Hours Spent on Each SRMA Task")

plt.tight_layout()
plt.savefig("./Exercises/figures/fig_3.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df3 = pd.DataFrame(np.array([
#       2         ["find previous or upcoming SR", 63],
#       3         ["deduplication", 16],
#       4         ["protocol", 175],
#
# NameError: name 'pd' is not defined

# %%
df3.head(15)
print(df3.to_markdown(index = False))
# Out:
# | task                         |   hours |
# |:-----------------------------|--------:|
# | find previous or upcoming SR |      63 |
# | deduplication                |      16 |
# | protocol                     |     175 |
# | search strategy              |     109 |
# | search                       |      72 |
# | title abstract screening     |     404 |
# | pdf                          |      41 |
# | full-text screening          |     187 |
# | trial registries screening   |     123 |
# | citation screening           |     201 |
# | forms                        |      72 |
# | extraction                   |     461 |
# | risk of bias                 |     323 |
# | meta-analysis                |     167 |
# | manuscript                   |     428 |

# %% [markdown]
# **References**
#
# [^1]: https://www.who.int/publications/i/item/9789240039872
# [^2]: https://www.cebm.ox.ac.uk/resources/levels-of-evidence/oxford-centre-for-evidence-based-medicine-levels-of-evidence-march-2009
# [^3]: https://pmc.ncbi.nlm.nih.gov/articles/PMC12487012/
# [^4]: https://bmjopen.bmj.com/content/7/2/e012545#DC1
# [^5]: https://www.sciencedirect.com/science/article/zpii/S089543561930719X

# %% [markdown]
# [1] https://www.who.int/publications/i/item/9789240039872
# [2] https://www.cebm.ox.ac.uk/resources/levels-of-evidence/oxford-centre-for-evidence-based-medicine-levels-of-evidence-march-2009
# [3] https://pmc.ncbi.nlm.nih.gov/articles/PMC12487012/
# [4] https://bmjopen.bmj.com/content/7/2/e012545#DC1
# [5] https://www.sciencedirect.com/science/article/pii/S089543561930719X
